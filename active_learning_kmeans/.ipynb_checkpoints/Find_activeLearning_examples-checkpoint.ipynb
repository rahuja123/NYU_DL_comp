# %%
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from PIL import Image # PIL is a library to process images
from matplotlib import pyplot as plt
    
import numpy as np

from sklearn.neighbors import NearestNeighbors
import sklearn.cluster as cluster

# %%
batch_size = 256;
def show_normalized_image(img, title=None, normalize=False):
    if normalize:
        plt.imshow(unnormalize(img).detach().cpu().permute(1, 2, 0))
    else: 
        plt.imshow(img.detach().cpu().permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    
train_transform = transforms.Compose([
        #transforms.RandomHorizontalFlip(),
        #transforms.functional.to_grayscale()
        #transforms.ColorJitter(hue=.1, saturation=.1, contrast=.1),
        #transforms.RandomRotation(20),
        #transforms.GaussianBlur(7, sigma=(0.1, 1.0)),
        transforms.ToTensor(),  # convert PIL to Pytorch Tensor
        #normalize,
    ])


trainset = CustomDataset(root='./dataset', split="unlabeled", transform=train_transform)
#trainset, validset = torch.utils.data.random_split(trainset, [25600, len(trainset)-25600], generator=torch.Generator().manual_seed(42))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=False, num_workers=4)
for epoch in range(1):
    running_loss = 0.0
    count =0;
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        count +=1
        plt.figure()
        show_normalized_image(inputs[0], 'input')
        #print(labels.shape)
        plt.figure()
        show_normalized_image(labels[0], 'label')
        if count ==10:
            break;

# %%
dataset_length = len(trainset)
idxs_unlabeled = np.arange(dataset_length)

# %%
def get_embedding(Dataloader, net):
    embedding = torch.zeros([dataset_length, 1000])
    with torch.no_grad():
        for i, batch in enumerate(trainloader):
            x_in = batch[0].to(device=device)
            e1 = net(x_in)
            embedding[i*batch_size:(i+1)*batch_size] = e1.cpu()
            if(i%100)==0:
                print(i*batch_size/dataset_length)
    return embedding

#get the desired samples
def kmeans_greed_query(samples_desired, embedding):
    embedding = embedding.numpy()
    #The lb_flag is only useful for keeping track of which values are labeled
    #If you can ask for data multiple times. As is it doesn't matter.

    cluster_learner = KMeans(n_clusters=samples_desired,  max_iter=20)
    cluster_learner.fit(embedding)
    cluster_idxs = cluster_learner.predict(embedding)
    centers = cluster_learner.cluster_centers_[cluster_idxs]
    dis = (embedding - centers)**2
    dis = dis.sum(axis=1)
    q_idxs = np.array([np.arange(embedding.shape[0])[cluster_idxs==i][dis[cluster_idxs==i].argmin()] for i in range(n)])

    return idxs_unlabeled[q_idxs] ,

# %%
net = models.resnet34(pretrained=True).to(device=device)
net.fc = identity()
# Out:
# 0.0
# 0.05
# 0.1
# 0.15
# 0.2
# 0.25
# 0.3
# 0.35
# 0.4
# 0.45
# 0.5
# 0.55
# 0.6
# 0.65
# 0.7
# 0.75
# 0.8
# 0.85
# 0.9
# 0.95

# %%
embed = get_embedding(trainloader, net)
np.save('embed_info', embed, allow_pickle=True, fix_imports=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-692f1f138ccf> in <module>
# ----> 1 np.save('embed_info', embed, allow_pickle=True, fix_imports=True)
#
# NameError: name 'embed' is not defined

# %%
embed = np.load('embed_info.npy')
# = embed[:100000]
from sklearn.decomposition import PCA
prinembedt(embed.shape)
pca = PCA(n_components=20)
pca.fit(embed)

# %%
compress = np.load('comp_info.npy')

# %%
compress = pca.transform(embed)

# %%
print(compress.shape)
# Out:
# (512000, 10)

# %%
samples_desired = 12800
embedding = embed#.numpy()
#The lb_flag is only useful for keeping track of which values are labeled
#If you can ask for data multiple times. As is it doesn't matter.
cluster_learner = cluster.MiniBatchKMeans(n_clusters=samples_desired,  max_iter=100, batch_size=60000, verbose=True)
cluster_learner.fit(embedding)
cluster_idxs = cluster_learner.predict(embedding)
centers = cluster_learner.cluster_centers_[cluster_idxs]
dis = (embedding - centers)**2
dis = dis.sum(axis=1)
# Out:
# Init 1/3 with method: k-means++
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-140816b11fad> in <module>
#       4 #If you can ask for data multiple times. As is it doesn't matter.
#       5 cluster_learner = cluster.MiniBatchKMeans(n_clusters=samples_desired,  max_iter=100, batch_size=60000, verbose=True)
# ----> 6 cluster_learner.fit(embedding)
#       7 cluster_idxs = cluster_learner.predict(embedding)
#       8 centers = cluster_learner.cluster_centers_[cluster_idxs]
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1717                 init=init,
#    1718                 random_state=random_state,
# -> 1719                 init_size=self._init_size)
#    1720
#    1721             # Compute the label assignment on the init dataset
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _init_centroids(self, X, x_squared_norms, init, random_state, init_size)
#     934             centers, _ = _kmeans_plusplus(X, n_clusters,
#     935                                           random_state=random_state,
# --> 936                                           x_squared_norms=x_squared_norms)
#     937         elif isinstance(init, str) and init == 'random':
#     938             seeds = random_state.permutation(n_samples)[:n_clusters]
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in _kmeans_plusplus(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     122         # Compute distances to center candidates
#     123         distance_to_candidates = euclidean_distances(
# --> 124             X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True)
#     125
#     126         # update closest distances squared and potential for each candidate
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     308         # To minimize precision issues with float32, we compute the distance
#     309         # matrix on chunks of X and Y upcast to float64
# --> 310         distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     311     else:
#     312         # if dtype is already float64, no need to chunk and upcast
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in _euclidean_distances_upcast(X, XX, Y, YY, batch_size)
#     494
#     495             else:
# --> 496                 Y_chunk = Y[y_slice].astype(np.float64)
#     497                 if YY is None:
#     498                     YY_chunk = row_norms(Y_chunk, squared=True)[np.newaxis, :]
#
# KeyboardInterrupt:

# %%
q_idxs = np.array([np.arange(embedding.shape[0])[cluster_idxs==i][dis[cluster_idxs==i].argmin()] for i in range(samples_desired)])
np.save('samples', q_idxs, allow_pickle=True, fix_imports=True)

# %%
np.save('samples_reduced_10', q_idxs, allow_pickle=True, fix_imports=True)

# %%
print(q_idxs[0:10])
# Out:
# [432793 445000 279298 228482 139679 398720 436507 411349 389928 159771]
